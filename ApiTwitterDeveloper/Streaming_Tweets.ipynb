# %% [markdown]
# ### Analisis Exploratorio de Tweets
# Para obtener los datos de Twitter debemos usar la API ingresa a (Twitter Developers) y luego necesitas generar tus credenciales. Para ello crea un nuevo proyecto, deberás ponerle un nombre, descripción y propósito.

# %%
import tweepy
import pandas as pd

# %% [markdown]
# ### Extraccion de Tweets
# Codigo Python para obtener todos los tweets por Cuenta (@) especifica de Twitter

# %%
import tweepy
import pandas as pd

api_key = "qmY35eMTVvwC0RSAE1Ug4UFoB"
api_key_secret = "OC0GrI0Au9MxTlHlH7YEdnbAPDhAlnyPw7qCK9zKnaOWmzF6e3"
access_token = "634148510-yjYEe3XmHFRZUbM5rEycfEbDJoq3dPXA3DL2w7yy"
access_token_secret = "vsRazXvDCyuYBidVd39lOPtR7EONJN9LkY2w1MJGpcFnw"

auth = tweepy.OAuth1UserHandler(
   api_key, api_key_secret, access_token, access_token_secret
)

api = tweepy.API(auth)

# Iniciamos un array que va a contener los datos
simple_list = []
# Iniciamos el for con Cursor
# Usamos algunos parámetros extra para excluir respuestas, retweets y traer el texto completo de cada tweet
for status in tweepy.Cursor(api.user_timeline,
                            screen_name = 'rofigueredo8', 
                            exclude_replies = True, 
                            include_rts = False,
                            tweet_mode='extended').items(70):
 # Agregamos el texto, fecha, likes, retweets y hashtags al array
    simple_list.append([status.full_text, status.created_at, status.favorite_count, status.retweet_count, [h['text'] for h in status.entities['hashtags']]])
# Convertimos el array en un DataFrame y nombramos las columnas
simple_list = pd.DataFrame(simple_list, columns=['Text', 'Created_at', 'Likes', 'Retweets', 'Hashtags'])
# Guardamos en el directorio en que estamos trabajando
simple_list
simple_list.to_csv("test3.csv", sep=';')

# %% [markdown]
# Conexion a Base de Datos Postgres

# %%
import psycopg2
from sqlalchemy import create_engine
conn_dwh = 'postgresql://postgres:Tailscale@localhost/postgres'
db = create_engine(conn_dwh)

# %% [markdown]
# Extraccion de Tweets por Palabras Claves

# %%
import tweepy
import pandas as pd

api_key = "qmY35eMTVvwC0RSAE1Ug4UFoB"
api_key_secret = "OC0GrI0Au9MxTlHlH7YEdnbAPDhAlnyPw7qCK9zKnaOWmzF6e3"
access_token = "634148510-yjYEe3XmHFRZUbM5rEycfEbDJoq3dPXA3DL2w7yy"
access_token_secret = "vsRazXvDCyuYBidVd39lOPtR7EONJN9LkY2w1MJGpcFnw"

auth = tweepy.OAuth1UserHandler(api_key, api_key_secret, access_token, access_token_secret)

api = tweepy.API(auth)

search_list = []
KEYWORDS = "Olimpia"

# Basic keyword search with full text
#tweets = api.search_tweets(KEYWORDS, tweet_mode="extended")

#Parámetros de la función search
for status in tweepy.Cursor(api.search_tweets, KEYWORDS, result_type="recent", tweet_mode="extended").items(55):
    search_list.append([status.full_text, status.created_at, status.favorite_count, status.retweet_count, status.lang, status.author.screen_name, status.id])

search_list = pd.DataFrame(search_list, columns=['tweettext', 'created_at', 'likes', 'retweets', 'idioma', 'autor', 'idtw'])
# Insert into table
# search_list
print('Filas insertadas')
#search_list.to_sql('olimpiatext', con=conn_dwh, index=False, if_exists='replace',chunksize = 1000)
search_list.to_sql('tweets_olimpia', con=conn_dwh, index=False, if_exists='replace',chunksize = 1000)
# Out:
# Filas insertadas
# 55

# %% [markdown]
# Consulta en la Base de Datos para comprobar

# %%
Query = "SELECT * FROM tweets_olimpia"
dfTweetsOlimpia = pd.read_sql_query(Query, conn_dwh)
dfTweetsOlimpia
# Out:
#                                             tweettext  \
# 0   RT @PedroRonchi2: A posse do Lula vai ter um d...
# 1   @AdrianaIndianas @FiscaliaNL Pues si sigues jo...
# 2   @Davidsccp999 @souchatonamesmo @CentralDoBraga...
# 3   RT @ANGSTRlNA: o son dizendo que o brasil tem ...
# 4   EU SOU ASSIM E NÃO TENHO VERGONHA DE SER https...
# 5   RT @Marcelo_Antunez: Imaginate si Trovato fuer...
# 6   RT @fireyeollie: Brincadeiras à parte a Coreia...
# 7   RT @TigoSportsPY: EL MISMO DESEO\nSergio Otálv...
# 8   RT @nanduti: Hay buena predisposición de Olimp...
# 9   RT @whomath: o richarlison e o son 😭😭😭😭 lindos...
# 10  RT @taewalIs: eu estou só o meme: lindo, lindo...
# 11  @Carlos8sizag @DiarioDiezHn Que se extraña, es...
# 12  RT @mayacoutza: Os gringos se ofendendo com as...
# 13  @tanyarodtvc Su equipo es un chiste mal contad...
# 14  RT @CentralDoBraga: “O Son tá triste”\n\nO Son...
# 15  RT @dinlenrau: não ironicamente pelo menos trê...
# ...

# %% [markdown]
# Conexion SQL Server a atraves de pyodbc

# %%
# Importamos la libreria par SQL Server
import pyodbc
import pandas as pd

# %%
#Paramentros de Conexion SQL SERVER con la base de datos: AdventureWorksDW2019
connAWdhw = pyodbc.connect('Driver={SQL Server};'
                      'Server=ASUSRF\SQLSERVER19;'
                      'Database=AdventureWorksDW2019;'
                      'Trusted_Connection=yes;')

# %%
#Lectura de datos con Cursor
cursor = conn.cursor()
cursor.execute('SELECT * FROM FactFinance')

for i in cursor:
    print(i)
# Out:
# (1, 20101229, 3, 1, 1, 60, 22080.0, datetime.datetime(2020, 12, 29, 0, 0))
# (2, 20101229, 3, 1, 2, 60, 20200.0, datetime.datetime(2020, 12, 29, 0, 0))
# (3, 20101229, 3, 1, 2, 61, 2000.0, datetime.datetime(2020, 12, 29, 0, 0))
# (4, 20101229, 3, 1, 1, 61, 2208.0, datetime.datetime(2020, 12, 29, 0, 0))
# (5, 20101229, 3, 1, 1, 62, 1546.0, datetime.datetime(2020, 12, 29, 0, 0))
# (6, 20101229, 3, 1, 2, 62, 1800.0, datetime.datetime(2020, 12, 29, 0, 0))
# (7, 20101229, 3, 1, 2, 65, 380.0, datetime.datetime(2020, 12, 29, 0, 0))
# (8, 20101229, 3, 1, 1, 65, 378.0, datetime.datetime(2020, 12, 29, 0, 0))
# (9, 20101229, 3, 1, 1, 66, 344.0, datetime.datetime(2020, 12, 29, 0, 0))
# (10, 20101229, 3, 1, 2, 66, 380.0, datetime.datetime(2020, 12, 29, 0, 0))
# (11, 20101229, 3, 1, 2, 67, 200.0, datetime.datetime(2020, 12, 29, 0, 0))
# (12, 20101229, 3, 1, 1, 67, 174.0, datetime.datetime(2020, 12, 29, 0, 0))
# (13, 20101229, 3, 1, 1, 68, 132.0, datetime.datetime(2020, 12, 29, 0, 0))
# ...

# %%
# Consulta a traves de Dataframe Pandas

sentencia_sql = "SELECT * FROM Deparmet"

lista_df = pd.read_sql_query(sentencia_sql, conn)
lista_df
# Out:
# C:\Users\rfigu\AppData\Local\Temp\ipykernel_16888\1482331816.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   lista_df = pd.read_sql_query(sentencia_sql, conn)
#        FinanceKey   DateKey  OrganizationKey  DepartmentGroupKey  ScenarioKey  \
# 0               1  20101229                3                   1            1
# 1               2  20101229                3                   1            2
# 2               3  20101229                3                   1            2
# 3               4  20101229                3                   1            1
# 4               5  20101229                3                   1            1
# ...           ...       ...              ...                 ...          ...
# 39404       39405  20131228               13                   7            1
# ...

# %%
query = "SELECT * from DimSalesReason;"
df = pd.read_sql_query(query, conn)

df.head(3)
# Out:
# C:\Users\rfigu\AppData\Local\Temp\ipykernel_16888\489737462.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
#    SalesReasonKey  SalesReasonAlternateKey         SalesReasonName  \
# 0               1                        1                   Price
# 1               2                        2            On Promotion
# 2               3                        3  Magazine Advertisement
#
#   SalesReasonReasonType
# 0                 Other
# 1             Promotion
# 2             Marketing

# %%
connAW2 = pyodbc.connect('Driver={SQL Server};'
                      'Server=ASUSRF\SQLSERVER19;'
                      'Database=AwfactTempo;'
                      'Trusted_Connection=yes;')

# %%
for index, row in lista_df.iterrows():
     cursor.execute("INSERT INTO AwfactTempo.FactFinance3 ([Financekey],[Datekey],[OrganizationKey],[DepartmentGroupKey],[ScenarioKey],[AccountKey],[Amount],[Date]) values (?,?,?,?,?,?,?,?)",
      row.Financekey,
      row.Datekey,
      row.OrganizationKey,
      row.DepartmentGroupKey,
      row.ScenarioKey,
      row.AccountKey,
      row.Amount,
      row.date)
connAW2.commit()
cursor.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\rfigu\Documents\GitLocal\twitterDes\extraerTweets.ipynb Celda 18 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/rfigu/Documents/GitLocal/twitterDes/extraerTweets.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> for index, row in lista_df.iterrows():
#       <a href='vscode-notebook-cell:/c%3A/Users/rfigu/Documents/GitLocal/twitterDes/extraerTweets.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a>      cursor.execute("INSERT INTO AwfactTempo.FactFinance3 ([Financekey],[Datekey],[OrganizationKey],[DepartmentGroupKey],[ScenarioKey],[AccountKey],[Amount],[Date]) values (?,?,?,?,?,?,?,?)",
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rfigu/Documents/GitLocal/twitterDes/extraerTweets.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>       row.Financekey,
# ...
